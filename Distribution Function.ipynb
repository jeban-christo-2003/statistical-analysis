# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
data = iris['sepal_length']

# %%
sorted_data = np.sort(data)
cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)

# %%
counts, bins = np.histogram(data, bins=30, density=True)
bin_centers = (bins[:-1] + bins[1:]) / 2
pdf = counts / sum(counts)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(sorted_data, cdf, label='CDF')
plt.title('Cumulative Distribution Function (CDF)')
plt.xlabel('Data')
plt.ylabel('Probability')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(bin_centers, pdf, label='PDF')
plt.title('Probability Density Function (PDF)')
plt.xlabel('Data')
plt.ylabel('Probability Density')
plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(sorted_data, cdf, label='CDF')
plt.title('Cumulative Distribution Function (CDF)')
plt.xlabel('Data')
plt.ylabel('Probability')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(bin_centers, pdf, label='PDF')
plt.title('Probability Density Function (PDF)')
plt.xlabel('Data')
plt.ylabel('Probability Density')
plt.legend()

# %%
mu = 0  
sigma = 1  
probabilities = np.linspace(0.01, 0.99, 99)

# %%
ppf_values = norm.ppf(probabilities, mu, sigma)
plt.figure(figsize=(8, 6))
plt.plot(probabilities, ppf_values, marker='o', linestyle='-')
plt.title('Percent Point Function (PPF)')
plt.xlabel('Probability')
plt.ylabel('PPF Value')
plt.grid(True)
plt.show()
